# %% [markdown]
# ## Simple geocoding with geopy and ipleaflet
#
# This notebook gives a very quick introduction to using geopy to find geospatial data from textual descriptions, and then plot it on a map using ipleaflet. We're using collection data in csv from the University of Melbourne Archives. This series of photographs is from the Commercial Travellers Association.

# %%
from geopy.geocoders import ArcGIS
import pandas as pd

data = pd.read_csv('CTA PHOTOGRAPHS.csv', index_col='Identifier')
data.head()
# Out:
#                 Level of description  \
# Identifier
# 1979.0162.02178                 Item
# 1979.0162.02179                 Item
# 1979.0162.02180                 Item
# 1979.0162.02181                 Item
# 1979.0162.02182                 Item
#
#                                                              Title  \
# Identifier
# 1979.0162.02178                                       Dagg's Falls
# 1979.0162.02179        View from Eagle Heights Tambourine Mountain
# 1979.0162.02180  View from Picnic Point Main Range, Toowoomba S...
# 1979.0162.02181  Carrington Falls near Herberton Cairns Distric...
# 1979.0162.02182  Olsen's Harp Caves 16 Miles NW from Rockhampto...
#
#                               Date  \
# Identifier
# 1979.0162.02178       c. 1929-1933
# 1979.0162.02179     21 August 1926
# 1979.0162.02180     21 August 1926
# 1979.0162.02181  15 September 1930
# 1979.0162.02182          1929-1933
#
#                                                        Description  \
# Identifier
# 1979.0162.02178  Black and white photograph, two men standing a...
# 1979.0162.02179  Black and white photograph, view from Eagle He...
# 1979.0162.02180  Black and white photograph, view of mountain s...
# 1979.0162.02181  Black and white photograph, man standing midwa...
# 1979.0162.02182  Black and white photograph, picture of stalagm...
#
#                                                           Location  \
# Identifier
# 1979.0162.02178             Dagg's Falls waterfall, QLD, Australia
# 1979.0162.02179  Eagle Heights Tambourine Mountain, QLD, Australia
# 1979.0162.02180            Picnic Point, Toowoomba, QLD, Australia
# 1979.0162.02181        Carrington Falls, Herberton, QLD, Australia
# 1979.0162.02182                 Olsen's Harp Caves, QLD, Australia
#
#                      Format  \
# Identifier
# 1979.0162.02178  Photograph
# 1979.0162.02179  Photograph
# 1979.0162.02180  Photograph
# 1979.0162.02181  Photograph
# 1979.0162.02182  Photograph
#
#                                                             Rights  \
# Identifier
# 1979.0162.02178  This image is out of copyright. It is provided...
# 1979.0162.02179  This image is out of copyright. It is provided...
# 1979.0162.02180  This image is out of copyright. It is provided...
# 1979.0162.02181  This image is out of copyright. It is provided...
# 1979.0162.02182  This image is out of copyright. It is provided...
#
#                 Contributor  Collection identifier  \
# Identifier
# 1979.0162.02178         NaN              1979.0162
# 1979.0162.02179         NaN              1979.0162
# 1979.0162.02180         NaN              1979.0162
# 1979.0162.02181         NaN              1979.0162
# 1979.0162.02182         NaN              1979.0162
#
#                                    Collection title Published online?  \
# Identifier
# 1979.0162.02178  Commercial Travellers' Association               Yes
# 1979.0162.02179  Commercial Travellers' Association               Yes
# 1979.0162.02180  Commercial Travellers' Association               Yes
# 1979.0162.02181  Commercial Travellers' Association               Yes
# 1979.0162.02182  Commercial Travellers' Association               Yes
#
#                  MulMultiMediaRefLocal_1  \
# Identifier
# 1979.0162.02178                    92663
# 1979.0162.02179                    92664
# 1979.0162.02180                    92665
# 1979.0162.02181                    92666
# 1979.0162.02182                    92667
#
#                                                                URL
# Identifier
# 1979.0162.02178  http://gallery.its.unimelb.edu.au/umblumaic/im...
# 1979.0162.02179  http://gallery.its.unimelb.edu.au/umblumaic/im...
# 1979.0162.02180  http://gallery.its.unimelb.edu.au/umblumaic/im...
# 1979.0162.02181  http://gallery.its.unimelb.edu.au/umblumaic/im...
# 1979.0162.02182  http://gallery.its.unimelb.edu.au/umblumaic/im...

# %% [markdown]
# Note that I have manually extracted location text into a separate column for the first 50 records. You may want to try automating this using named entity recognition, regular expressions or another method.
#
# Next we're going to use geopy to lookup location data and extract it into a separate column. I'm using the ArcGIS service, but there are many others wrapped in geopy.

# %%
geolocator = ArcGIS()
from numpy import NaN
def find_coords(text):
    if text is not NaN:
        return geolocator.geocode(text)
    
data['coords'] = data['Location'].apply(find_coords)

# %% [markdown]
# Now we have our location data, we can put it on a map. We're aqlso going to add popup messages with basic metadata and a link back to the UMA catalogue record.

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker, Popup
from ipywidgets import HTML


def make_popup(ident, row):
    message = HTML()
    thumb = f"https://gallery.its.unimelb.edu.au/umblumaic/imu.php?request=multimedia&irn={row['MulMultiMediaRefLocal_1']}&bestfit=yes&width=200" 
    message.value = f"""<table style="float:right">
    <tr><td><table>
    <tr><td style="padding:5px">Identifier</td><td>{ident}</td></tr>
    <tr><td style="padding:5px">Title</td><td>{row['Title']}</td></tr>
    <tr><td style="padding:5px">Date</td><td>{row['Date']}</td></tr></table></td>
    <td style="padding:5px"><a href="{row['URL']}" target="_blank"><img src="{thumb}" width="200"/></a></td>
    </tr>
    </table>"""
    return message


c = geolocator.geocode('Australia')
m = Map(basemap=basemap_to_tiles(basemaps.CartoDB.Positron), zoom=4, center=(c.latitude, c.longitude))

for ident, row in data.iterrows():
    if row['coords'] != None:
        marker = Marker(
            location=(row['coords'].latitude, row['coords'].longitude),
            draggable=False, title=ident+': '+row['Title'])
        marker.popup = make_popup(ident, row)
        m.add_layer(marker)
m
# Out:
# Map(center=[-25.70993156999998, 134.48403119800003], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %% [markdown]
# Not bad! We do have some dodgy locations in there, and there's other metadata elements like dates we've done nothing with. Have a think about what this metadata enabels and what it's major drawbacks are in terms of reuse. However, note that if we have multiple images with the same location, we're not going to see them all. So another approach we can take is to contruct a gallery popup for each location.

# %%
from xml.etree import ElementTree as ET
import math

def make_itemtable_popup(rows):
    message = HTML()
    num_cols = math.ceil(math.sqrt(len(rows)))
    table = ET.Element('table', style=f"width: {100*num_cols}px")
    t_row = ET.Element('tr')
    table.append(t_row)
    col = 0
    for row in rows:
        col += 1
        if col > num_cols:
            t_row = ET.Element('tr')
            table.append(t_row)
            col = 1
        t_cell = ET.Element('td', style="padding:5px")
        t_row.append(t_cell)
        link = ET.Element('a', href=row['URL'], target="_blank")
        t_cell.append(link)
        thumb = f"https://gallery.its.unimelb.edu.au/umblumaic/imu.php?request=multimedia&irn={row['MulMultiMediaRefLocal_1']}&bestfit=yes&width=200" 
        image = ET.Element('img', src=thumb, alt=f"row['Title']")
        link.append(image)
    message.value = ET.tostring(table, encoding='utf8', method='html').decode()
    return message

places = {}
for ident, row in data.iterrows():
    if row['coords'] != None:
        coords = (row['coords'].latitude, row['coords'].longitude, row['coords'].address)
        if coords in places.keys():
            places[coords].append(row)
        else:
            places[coords] = [row]
    

m2 = Map(basemap=basemap_to_tiles(basemaps.CartoDB.Positron), zoom=4, center=(c.latitude, c.longitude))

for coords, rows in places.items():
    marker = Marker(location=coords[:2], draggable=False, title=coords[2])
    marker.popup = make_itemtable_popup(rows)
    m2.add_layer(marker)
m2
# Out:
# Map(center=[-25.70993156999998, 134.48403119800003], controls=(ZoomControl(options=['position', 'zoom_in_text'…
